# %% [markdown]
# <a href="https://colab.research.google.com/github/laksamanaap/244107020021-machine-leaning-course-2026-/blob/main/JS02/JS02_TugasLab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
df = pd.read_csv('wbc.csv')

# %%
kolom_dibuang = ['id', 'Unnamed: 32']
df_clean = df.drop(columns=kolom_dibuang)

# %%
target = df_clean['diagnosis']
fitur_numerik = df_clean.drop(columns=['diagnosis'])

# %%
label_encoder = LabelEncoder()
target_encoded = label_encoder.fit_transform(target)
df_clean['diagnosis'] = target_encoded

# %%
scaler = StandardScaler()
fitur_scaled = scaler.fit_transform(fitur_numerik)

# %%
df_scaled = pd.DataFrame(fitur_scaled, columns=fitur_numerik.columns)
df_scaled.insert(0, 'diagnosis', target_encoded)

# %%
print("Ukuran dataset setelah dibersihkan:", df_scaled.shape)
print(df_scaled.head())
# Out:
# Ukuran dataset setelah dibersihkan: (569, 31)
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1     1.097064     -2.073335        1.269934   0.984375
# 1          1     1.829821     -0.353632        1.685955   1.908708
# 2          1     1.579888      0.456187        1.566503   1.558884
# 3          1    -0.768909      0.253732       -0.592687  -0.764464
# 4          1     1.750297     -1.151816        1.776573   1.826229
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0         1.568466          3.283515        2.652874             2.532475
# 1        -0.826962         -0.487072       -0.023846             0.548144
# 2         0.942210          1.052926        1.363478             2.037231
# 3         3.283553          3.402909        1.915897             1.451707
# 4         0.280372          0.539340        1.371011             1.428493
#
# ...
